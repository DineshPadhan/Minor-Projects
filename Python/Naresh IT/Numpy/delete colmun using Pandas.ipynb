# %%
import pandas as pd

# %%
df = pd.read_csv("./csv_result/adding new data in dataframe.csv")
df
# Out:
#     Unnamed: 0   id     Name  Phy  Che  Math  IT  total  Percentage Grade
# 0            0    1   Trudie   99   95    82  82    358       89.50     A
# 1            1    2     Sean   95   72    96  75    338       84.50     A
# 2            2    3  Chloris   54   73    57  94    278       69.50     B
# 3            3    4  Iseabal   77   64    83  99    323       80.75     A
# 4            4    5  Maridel   96   58    98  92    344       86.00     A
# ..         ...  ...      ...  ...  ...   ...  ..    ...         ...   ...
# 95          95   96    Helsa   60   73    81  85    299       74.75     B
# 96          96   97  Kristan   87   50    72  98    307       76.75     B
# 97          97   98   Ginnie   89   65    83  79    316       79.00     B
# 98          98   99    Aimil   81   98    67  96    342       85.50     A
# 99          99  100   Collen   58   57    61  97    273       68.25     B
#
# [100 rows x 10 columns]

# %%
df.sort_values(["Percentage"])      # ascending
# Out:
#     Unnamed: 0  id        Name  Phy  Che  Math  IT  total  Percentage Grade
# 86          86  87       Janey   50   53    65  73    241       60.25     B
# 85          85  86       Daryl   51   70    54  71    246       61.50     B
# 61          61  62      Jackie   53   71    50  73    247       61.75     B
# 69          69  70      Shauna   70   57    54  77    258       64.50     B
# 81          81  82  Dianemarie   50   61    64  85    260       65.00     B
# ..         ...  ..         ...  ...  ...   ...  ..    ...         ...   ...
# 91          91  92       Clary   78   86    85  98    347       86.75     A
# 84          84  85        Mary   93   88    80  92    353       88.25     A
# 39          39  40      Andree   91   98    81  85    355       88.75     A
# 0            0   1      Trudie   99   95    82  82    358       89.50     A
# 28          28  29      Marnia   97   72    94  96    359       89.75     A
#
# [100 rows x 10 columns]

# %%
df.sort_values(["Percentage"])[::-1]    # descending
# Out:
#     Unnamed: 0  id        Name  Phy  Che  Math  IT  total  Percentage Grade
# 28          28  29      Marnia   97   72    94  96    359       89.75     A
# 0            0   1      Trudie   99   95    82  82    358       89.50     A
# 39          39  40      Andree   91   98    81  85    355       88.75     A
# 84          84  85        Mary   93   88    80  92    353       88.25     A
# 91          91  92       Clary   78   86    85  98    347       86.75     A
# ..         ...  ..         ...  ...  ...   ...  ..    ...         ...   ...
# 81          81  82  Dianemarie   50   61    64  85    260       65.00     B
# 69          69  70      Shauna   70   57    54  77    258       64.50     B
# 61          61  62      Jackie   53   71    50  73    247       61.75     B
# 85          85  86       Daryl   51   70    54  71    246       61.50     B
# 86          86  87       Janey   50   53    65  73    241       60.25     B
#
# [100 rows x 10 columns]

# %%
df.sort_values(["Percentage"], ascending=False)     # descending
# Out:
#     Unnamed: 0  id        Name  Phy  Che  Math  IT  total  Percentage Grade
# 28          28  29      Marnia   97   72    94  96    359       89.75     A
# 0            0   1      Trudie   99   95    82  82    358       89.50     A
# 39          39  40      Andree   91   98    81  85    355       88.75     A
# 84          84  85        Mary   93   88    80  92    353       88.25     A
# 26          26  27     Dorothy   95   76    89  87    347       86.75     A
# ..         ...  ..         ...  ...  ...   ...  ..    ...         ...   ...
# 81          81  82  Dianemarie   50   61    64  85    260       65.00     B
# 69          69  70      Shauna   70   57    54  77    258       64.50     B
# 61          61  62      Jackie   53   71    50  73    247       61.75     B
# 85          85  86       Daryl   51   70    54  71    246       61.50     B
# 86          86  87       Janey   50   53    65  73    241       60.25     B
#
# [100 rows x 10 columns]

# %%
df1 = df.drop(columns="total")
df1
# Out:
#     Unnamed: 0   id     Name  Phy  Che  Math  IT  Percentage Grade
# 0            0    1   Trudie   99   95    82  82       89.50     A
# 1            1    2     Sean   95   72    96  75       84.50     A
# 2            2    3  Chloris   54   73    57  94       69.50     B
# 3            3    4  Iseabal   77   64    83  99       80.75     A
# 4            4    5  Maridel   96   58    98  92       86.00     A
# ..         ...  ...      ...  ...  ...   ...  ..         ...   ...
# 95          95   96    Helsa   60   73    81  85       74.75     B
# 96          96   97  Kristan   87   50    72  98       76.75     B
# 97          97   98   Ginnie   89   65    83  79       79.00     B
# 98          98   99    Aimil   81   98    67  96       85.50     A
# 99          99  100   Collen   58   57    61  97       68.25     B
#
# [100 rows x 9 columns]

# %%
df1.drop(columns="IT", inplace=True)
df1
# Out:
#     Unnamed: 0   id     Name  Phy  Che  Math  Percentage Grade
# 0            0    1   Trudie   99   95    82       89.50     A
# 1            1    2     Sean   95   72    96       84.50     A
# 2            2    3  Chloris   54   73    57       69.50     B
# 3            3    4  Iseabal   77   64    83       80.75     A
# 4            4    5  Maridel   96   58    98       86.00     A
# ..         ...  ...      ...  ...  ...   ...         ...   ...
# 95          95   96    Helsa   60   73    81       74.75     B
# 96          96   97  Kristan   87   50    72       76.75     B
# 97          97   98   Ginnie   89   65    83       79.00     B
# 98          98   99    Aimil   81   98    67       85.50     A
# 99          99  100   Collen   58   57    61       68.25     B
#
# [100 rows x 8 columns]

# %%
df1.drop(columns=df1.columns[7])
# Out:
#     Unnamed: 0   id     Name  Phy  Che  Math  Percentage
# 0            0    1   Trudie   99   95    82       89.50
# 1            1    2     Sean   95   72    96       84.50
# 2            2    3  Chloris   54   73    57       69.50
# 3            3    4  Iseabal   77   64    83       80.75
# 4            4    5  Maridel   96   58    98       86.00
# ..         ...  ...      ...  ...  ...   ...         ...
# 95          95   96    Helsa   60   73    81       74.75
# 96          96   97  Kristan   87   50    72       76.75
# 97          97   98   Ginnie   89   65    83       79.00
# 98          98   99    Aimil   81   98    67       85.50
# 99          99  100   Collen   58   57    61       68.25
#
# [100 rows x 7 columns]

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.drop_duplicates()
# Out:
#     Unnamed: 0   id     Name  Phy  Che  Math  IT  total  Percentage Grade
# 0            0    1   Trudie   99   95    82  82    358       89.50     A
# 1            1    2     Sean   95   72    96  75    338       84.50     A
# 2            2    3  Chloris   54   73    57  94    278       69.50     B
# 3            3    4  Iseabal   77   64    83  99    323       80.75     A
# 4            4    5  Maridel   96   58    98  92    344       86.00     A
# ..         ...  ...      ...  ...  ...   ...  ..    ...         ...   ...
# 95          95   96    Helsa   60   73    81  85    299       74.75     B
# 96          96   97  Kristan   87   50    72  98    307       76.75     B
# 97          97   98   Ginnie   89   65    83  79    316       79.00     B
# 98          98   99    Aimil   81   98    67  96    342       85.50     A
# 99          99  100   Collen   58   57    61  97    273       68.25     B
#
# [100 rows x 10 columns]

# %%
for grpName, rows in df.groupby('Name'):
	
    print("Group Name: ", grpName)
    print('Group Content: ')
    print(rows)
    print("============================")
# Out:
# Group Name:  Agnese
# Group Content:
#     Unnamed: 0  id    Name  Phy  Che  Math  IT  total  Percentage Grade
# 32          32  33  Agnese   86   63    58  86    293       73.25     B
# ...
# Group Name:  Aimil
# Group Content:
#     Unnamed: 0  id   Name  Phy  Che  Math  IT  total  Percentage Grade
# 98          98  99  Aimil   81   98    67  96    342        85.5     A
# ...
# Group Name:  Andeee
# Group Content:
#     Unnamed: 0  id    Name  Phy  Che  Math  IT  total  Percentage Grade
# 24          24  25  Andeee   74   67    65  71    277       69.25     B
# ...
# Group Name:  Andree
# Group Content:
#     Unnamed: 0  id    Name  Phy  Che  Math  IT  total  Percentage Grade
# 39          39  40  Andree   91   98    81  85    355       88.75     A
# ...
# Group Name:  Atlanta
# Group Content:
#     Unnamed: 0  id     Name  Phy  Che  Math  IT  total  Percentage Grade
# 74          74  75  Atlanta   94   58    62  88    302        75.5     B
# ...
# Group Name:  Babita
# Group Content:
# ...
