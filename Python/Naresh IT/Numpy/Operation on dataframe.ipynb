# %%
import pandas as pd

# %%
df = pd.read_csv("./Student_details.csv")
df
# Out:
#      id     Name  Phy  Che  Math  IT
# 0     1   Trudie   99   95    82  82
# 1     2     Sean   95   72    96  75
# 2     3  Chloris   54   73    57  94
# 3     4  Iseabal   77   64    83  99
# 4     5  Maridel   96   58    98  92
# ..  ...      ...  ...  ...   ...  ..
# 95   96    Helsa   60   73    81  85
# 96   97  Kristan   87   50    72  98
# 97   98   Ginnie   89   65    83  79
# 98   99    Aimil   81   98    67  96
# 99  100   Collen   58   57    61  97
#
# [100 rows x 6 columns]

# %%
# Accessing DF from heading
df.head()
# Out:
#    id     Name  Phy  Che  Math  IT
# 0   1   Trudie   99   95    82  82
# 1   2     Sean   95   72    96  75
# 2   3  Chloris   54   73    57  94
# 3   4  Iseabal   77   64    83  99
# 4   5  Maridel   96   58    98  92

# %%
df.head(3)
# Out:
#    id     Name  Phy  Che  Math  IT
# 0   1   Trudie   99   95    82  82
# 1   2     Sean   95   72    96  75
# 2   3  Chloris   54   73    57  94

# %%
# Accessing DF from bottom
df.tail()
# Out:
#      id     Name  Phy  Che  Math  IT
# 95   96    Helsa   60   73    81  85
# 96   97  Kristan   87   50    72  98
# 97   98   Ginnie   89   65    83  79
# 98   99    Aimil   81   98    67  96
# 99  100   Collen   58   57    61  97

# %%
df.tail(2)
# Out:
#      id    Name  Phy  Che  Math  IT
# 98   99   Aimil   81   98    67  96
# 99  100  Collen   58   57    61  97

# %%
df.shape
# Out:
# (100, 6)

# %%
df.describe()
# Out:
#                id         Phy        Che        Math         IT
# count  100.000000  100.000000  100.00000  100.000000  100.00000
# mean    50.500000   75.350000   74.63000   72.640000   85.27000
# std     29.011492   14.081563   13.56887   13.773434    8.81786
# min      1.000000   50.000000   50.00000   50.000000   70.00000
# 25%     25.750000   67.250000   64.75000   61.000000   78.00000
# 50%     50.500000   75.500000   73.00000   72.000000   86.00000
# 75%     75.250000   87.250000   87.00000   83.000000   93.00000
# max    100.000000   99.000000   99.00000  100.000000  100.00000

# %%
for record in df.iterrows():
    print(record)
    print("--------------------------")
# Out:
# (0, id           1
# Name    Trudie
# Phy         99
# Che         95
# Math        82
# IT          82
# Name: 0, dtype: object)
# --------------------------
# (1, id         2
# Name    Sean
# Phy       95
# Che       72
# Math      96
# IT        75
# Name: 1, dtype: object)
# --------------------------
# (2, id            3
# Name    Chloris
# Phy          54
# Che          73
# Math         57
# IT           94
# Name: 2, dtype: object)
# --------------------------
# (3, id            4
# Name    Iseabal
# Phy          77
# Che          64
# Math         83
# IT           99
# Name: 3, dtype: object)
# --------------------------
# (4, id            5
# Name    Maridel
# Phy          96
# Che          58
# Math         98
# IT           92
# Name: 4, dtype: object)
# --------------------------
# (5, id          6
# Name    Diena
# Phy        88
# Che        73
# Math       69
# IT         78
# Name: 5, dtype: object)
# --------------------------
# (6, id           7
# ...

# %%
df
# Out:
#      id     Name  Phy  Che  Math  IT
# 0     1   Trudie   99   95    82  82
# 1     2     Sean   95   72    96  75
# 2     3  Chloris   54   73    57  94
# 3     4  Iseabal   77   64    83  99
# 4     5  Maridel   96   58    98  92
# ..  ...      ...  ...  ...   ...  ..
# 95   96    Helsa   60   73    81  85
# 96   97  Kristan   87   50    72  98
# 97   98   Ginnie   89   65    83  79
# 98   99    Aimil   81   98    67  96
# 99  100   Collen   58   57    61  97
#
# [100 rows x 6 columns]

# %%
df[20:31]
# Out:
#     id       Name  Phy  Che  Math  IT
# 20  21  Elbertina   77   81    61  80
# 21  22  Josephine   68   74    58  80
# 22  23     Kylynn   51   83    76  89
# 23  24       Viki   72   59    67  96
# 24  25     Andeee   74   67    65  71
# 25  26     Carree   57   87   100  71
# 26  27    Dorothy   95   76    89  87
# 27  28      Netty   91   90    72  80
# 28  29     Marnia   97   72    94  96
# 29  30    Madalyn   68   61    60  86
# 30  31    Pamella   77   58    83  78

# %%
df[10:51:5]
# Out:
#     id       Name  Phy  Che  Math  IT
# 10  11       Mary   78   78    84  78
# 15  16      Randa   91   82    65  95
# 20  21  Elbertina   77   81    61  80
# 25  26     Carree   57   87   100  71
# 30  31    Pamella   77   58    83  78
# 35  36       Beth   88   93    57  99
# 40  41    Evaleen   86   74    73  83
# 45  46     Lauryn   75   53    66  71
# 50  51    Viviene   58   95    55  97

# %%
df[::5]
# Out:
#     id       Name  Phy  Che  Math  IT
# 0    1     Trudie   99   95    82  82
# 5    6      Diena   88   73    69  78
# 10  11       Mary   78   78    84  78
# 15  16      Randa   91   82    65  95
# 20  21  Elbertina   77   81    61  80
# 25  26     Carree   57   87   100  71
# 30  31    Pamella   77   58    83  78
# 35  36       Beth   88   93    57  99
# 40  41    Evaleen   86   74    73  83
# 45  46     Lauryn   75   53    66  71
# 50  51    Viviene   58   95    55  97
# 55  56     Phedra   78   54    86  92
# 60  61  Cassondra   63   55    98  77
# 65  66    Clarice   92   87    55  90
# 70  71     Ericka   62   53    72  79
# 75  76      Marti   72   67    79  96
# 80  81      Blake   72   69    66  76
# 85  86      Daryl   51   70    54  71
# 90  91     Lonnie   71   65    58  97
# 95  96      Helsa   60   73    81  85

# %%
df[::-1]
# Out:
#      id     Name  Phy  Che  Math  IT
# 99  100   Collen   58   57    61  97
# 98   99    Aimil   81   98    67  96
# 97   98   Ginnie   89   65    83  79
# 96   97  Kristan   87   50    72  98
# 95   96    Helsa   60   73    81  85
# ..  ...      ...  ...  ...   ...  ..
# 4     5  Maridel   96   58    98  92
# 3     4  Iseabal   77   64    83  99
# 2     3  Chloris   54   73    57  94
# 1     2     Sean   95   72    96  75
# 0     1   Trudie   99   95    82  82
#
# [100 rows x 6 columns]

# %%
df[10::-1]
# Out:
#     id       Name  Phy  Che  Math  IT
# 10  11       Mary   78   78    84  78
# 9   10    Fanchon   56   97    88  74
# 8    9  Esmeralda   72   78    72  97
# 7    8    Raquela   70   68    93  91
# 6    7     Nannie   69   83    74  85
# 5    6      Diena   88   73    69  78
# 4    5    Maridel   96   58    98  92
# 3    4    Iseabal   77   64    83  99
# 2    3    Chloris   54   73    57  94
# 1    2       Sean   95   72    96  75
# 0    1     Trudie   99   95    82  82

# %%
df["Name"]
# Out:
# 0      Trudie
# 1        Sean
# 2     Chloris
# 3     Iseabal
# 4     Maridel
#        ...
# 95      Helsa
# 96    Kristan
# 97     Ginnie
# 98      Aimil
# 99     Collen
# Name: Name, Length: 100, dtype: object

# %%
df[["id","Name"]]
# Out:
#      id     Name
# 0     1   Trudie
# 1     2     Sean
# 2     3  Chloris
# 3     4  Iseabal
# 4     5  Maridel
# ..  ...      ...
# 95   96    Helsa
# 96   97  Kristan
# 97   98   Ginnie
# 98   99    Aimil
# 99  100   Collen
#
# [100 rows x 2 columns]
